# %% [markdown]
# ![day24_HW](images/day24_HW.jpg)

# %% [markdown]
# #### 📌 訓練結果好不好？
#
# #### ❌ 不好，模型明顯 過度擬合（Overfitting）。
#
# ◆ 判斷依據
#
# - Training Loss 持續下降、Training Accuracy 一直上升
#
# - 但 Validation Loss 上升、Validation Accuracy 停在低點甚至下降
#
# - 代表模型只記住 training，不會泛化。

# %% [markdown]
# ### 📌 如何改善模型的準確度？
#
# 以下為最常見、直接有效的 6 種方法：
#
# 1️⃣ 增加正則化（Regularization）
#
# - L2（weight decay）
#
# - dropout（例如 0.3~0.5）
#
# 可避免模型記住訓練資料太多細節。
#
# 2️⃣ 加入 Early Stopping
#
# 在 validation loss 開始上升時就停止訓練，可避免過度擬合。
#
# 3️⃣ 降低模型複雜度
#
# - 減少層數
#
# - 減少每層的神經元數，避免模型太大記太多東西。
#
# 4️⃣ 資料增強（Data Augmentation）
#
# 若是影像：翻轉、旋轉、亮度調整
# 若不是影像：可採 oversampling、noise injection
# → 增強模型泛化能力。
#
# 5️⃣ 增加訓練資料量
#
# 若資料太少，非常容易 overfit。
#
# 6️⃣ 調整 Learning Rate
#
# - 過大 → 震盪、學不到好解
#
# - 過小 → 容易卡在某些區域導致 validation 停滯
#
# 可使用 learning rate scheduler。
