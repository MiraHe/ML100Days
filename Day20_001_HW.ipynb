# %% [markdown]
# ## [作業]
# - 請用最小平方法推導多元迴歸（multiple regression）的公式解（請使用向量表示）。

# %% [markdown]
# D:\Github\ML100Days\homework\images\my_pic.png

# %% [markdown]
# ![day20_step0](images/day20_step0.jpg)

# %% [markdown]
# ![day20_step1](images/day20_step1.jpg)

# %% [markdown]
# ![day20_step2-6](images/day20_step2-6.jpg)
