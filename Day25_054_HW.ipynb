# %% [markdown]
# # 作業
# * 試著想想看, 非監督學習是否有可能使用評價函數 (Metric) 來鑑別好壞呢?
# (Hint : 可以分為 "有目標值" 與 "無目標值" 兩個方向思考)

# %% [markdown]
# ### 📌 1. 有目標值（semi-supervised / evaluation only）
#
# 雖然模型訓練沒有 y，但如果 最後有真實標籤可比對，就能用監督式指標來評估：
#
# ✔ 可用的指標：
#
# 1. ARI（Adjusted Rand Index）
#
# 2. NMI（Normalized Mutual Information）
#
# 3. Purity（純度）
#
# 4. F1-score / Accuracy（利用 cluster label 與真實 label 做 mapping）
#
# 👉 評估「分群結果與真實分類的一致程度」。

# %% [markdown]
# ### 📌 2. 無目標值（純非監督）
#
# 完全沒有 y 時，只能用數據結構本身評估分群、降維效果：
#
# ✔ 可用的指標：
#
# 1. SSE / inertia（群內距離）
#
# 2. Silhouette Score（輪廓係數）
#
# 3. Davies–Bouldin Index（DBI）
#
# 4. Calinski–Harabasz Index
#
# 👉 看「同群是否緊密、不同群是否分開」。
