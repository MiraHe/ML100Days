# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?

# %% [markdown]
# 領域：金融風險管理與信用評分
#
# 豐富的結構化數據：金融業累積大量客戶交易、還款、逾期等歷史數據，這些都是機器學習的絕佳訓練素材
#
# 明確的預測目標：像是預測客戶違約機率、延滯風險、信用評等等，都有清晰的目標變數
#
# 實際業務價值：
#
# 1.提早識別高風險客戶，降低呆帳損失
#
# 2.優化授信決策流程
#
# 3.動態調整風險定價策略
#
#
# 實務：資料欄位（延滯天數、逾期次數、備呆金額、異常客群等），這些都是訓練風險預測模型的重要特徵
#
# 可持續改進：隨著新數據不斷累積，模型可以持續學習和優化，提升預測準確度
#
# 具體應用例子：
# 1.建立信用評分模型取代傳統規則式評分
#
# 2.預測客戶未來 3-6 個月的逾期機率
#
# 3.識別異常交易模式進行預警
