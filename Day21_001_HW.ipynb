# %% [markdown]
# ## [作業]
# - 請查詢牛頓法（Newton's method）的資料，並且描述牛頓法的原理及其求解過程。請列出牛頓法的優缺點（各三點），以及與梯度下降法的不同。

# %% [markdown]
# ##### 原理
# - 在目前點 𝑥𝑘對 f(x) 作一階泰勒展開，用切線與 x 軸的交點當作下一次迭代。

# %% [markdown]
# ##### 求解公式
# ![day21_solve](images/day21_solve.jpg)

# %% [markdown]
# ### ✅ 優點（3點）
#
# - 收斂速度快：通常為二次收斂，比梯度下降快很多。
#
# - 迭代次數少：常常幾步就到解。
#
# - 不需要學習率（learning rate）。

# %% [markdown]
# ### ❌ 缺點（3點）
#
# - 需要計算導數（甚至二階），不適用複雜函數。
#
# - 若 f'(x)=0 或非常小，可能跳飛或失敗。
#
# - 對初始值敏感，選不好會不收斂。

# %% [markdown]
# ![day21](images/day21.jpg)

# %% [markdown]
# D:\Github\ML100Days\homework\images\my_pic.png
