# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %%
# Out:
# The Mean Square Error is 0.375

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error():
    """
    請完成這個 Function 後往下執行
    """

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
import numpy as np

# 定義 MAE
def mean_absolute_error(y, y_hat):
    y = np.array(y)
    y_hat = np.array(y_hat)
    return np.mean(np.abs(y - y_hat))

# 定義 MSE
def mean_squared_error(y, y_hat):
    y = np.array(y)
    y_hat = np.array(y_hat)
    return np.mean((y - y_hat) ** 2)

# 測試資料
y = [3, -0.5, 2, 7]
y_hat = [2.5, 0.0, 2, 8]

# 執行 Function
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)

print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 0.375
# The Mean absolute error is 0.500

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 0.375
# The Mean absolute error is 0.500

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
#    🔹先行了解未來若需貸款可以如何評估。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#    🔹從在貸款預測資料集上由深度學習模型訓練產生的。
#
# 3. 蒐集而來的資料型態為何
#
#    🔹欄位名稱	資料型態	說明
#    🔹id	int64	整數編號
#    🔹annual_income	float64	年收入（有小數點）
#    🔹debt_to_income_ratio	float64	負債比率（小數）
#    🔹credit_score	int64	信用分數（整數）
#    🔹loan_amount	float64	貸款金額（含小數）
#    🔹interest_rate	float64	利率（含小數）
#    🔹gender	object	性別（文字類別）
#    🔹marital_status	object	婚姻狀態（文字類別）
#    🔹education_level	object	教育程度（文字類別）
#    🔹employment_status	object	就業狀況（文字類別）
#    🔹loan_purpose	object	貸款用途（文字類別）
#    🔹grade_subgrade	object	信用等級（文字類別）
#    l🔹oan_paid_back	int64	是否還款（0/1）→ 可視為整數或布林
#
# 4. 這組資料想解決的問題如何評估
#
#    🔹預測借款人償還貸款的機率。根據預測機率和觀察目標之間的 ROC 曲線下面積進行評估。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#    定義「提升業績」：
#    業績可透過以下指標衡量：
#    🔹每日/每月總營收（Revenue）
#    🔹單位時間接單數（Order per hour）
#    🔹平均載客率（Occupied time / Total time）
#    🔹乘客滿意度（留存率 / 再次搭乘率）
#
#    假設：
#    🔹接單效率與業績呈正相關（司機閒置時間越少、營收越高）。
#    🔹高峰時段與地點若能精準預測並派車，能顯著提升營收。
#    🔹優化價格策略（如高峰加價、會員折扣）能提升使用率與乘客留存率。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#    | 類別         | 內容                            | 蒐集方式                 |
#
#    | 🚖 車隊營運資料  | 司機接單紀錄、訂單時間、金額、起訖地點、乘客評價、等待時間 | 來自後台系統或APP API log   |
#
#    | 👨‍✈️ 司機資料 | 司機編號、工作時段、駕駛年資、平均評分、線上時間      | 車隊內部註冊資料庫            |
#
#    | 🚦 外部環境資料  | 天氣、節假日、交通狀況、活動資訊              | 第三方 API（氣象局、交通部開放資料） |
#
#    | 💬 乘客服務資料  | 乘客服訴、滿意度調查、App 評價             | App 問卷、客服系統          |
#
#    | 💰 收費策略資料  | 動態定價、優惠活動、會員制度                | 行銷部門紀錄或後台資料          |
#
#
#
#
# 3. 蒐集而來的資料型態為何
#
#
#    | 資料欄位                               | 資料型態             | 範例                  |
#
#    | driver_id / passenger_id           | 整數 (int)         | 10234               |
#
#    | trip_start_time / trip_end_time    | 時間 (datetime)    | 2025-11-12 08:32    |
#
#    | pickup_location / dropoff_location | 文字 (string)      | Taipei Main Station |
#
#    | fare_amount                        | 浮點數 (float)      | 320.5               |
#
#    | trip_distance                      | 浮點數 (float)      | 7.3                 |
#
#    | weather / traffic_condition        | 分類 (categorical) | Rainy / Heavy       |
#
#    | driver_rating / passenger_rating   | 數值 (float)       | 4.8                 |
#
#    | coupon_used                        | 布林 (boolean)     | True / False        |
#
#    | weekday / hour                     | 整數 (int)         | 2 / 18              |
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#    | 假設            | 驗證方式                    | 成效指標            |
#
#    | 派車精準度提升可增加業績  | 比較模型前後每小時平均接單數、平均等待時間   | 接單率 ↑、等待時間 ↓    |
#
#    | 動態定價可提升營收     | A/B Test：區分不同價格區域觀察收入變化 | 平均營收 ↑、留存率持平或上升 |
#
#    | 乘客滿意度提升能帶動再搭乘 | 分析評分與回流率關聯              | 留存率 ↑、NPS ↑     |
